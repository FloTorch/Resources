# %% [markdown]
# ## Loan Underwriter Agent (FloTorch Variant)
#
# This notebook demonstrate executing a simple agentic workflow for Loan Underwriter use case.
#
# There are 3 agents operating in this workflow:
#
# 1. Loan Officer - Summarizes the application.
# 2. Credit Analyst - Evaluates creditworthiness.
# 3. Risk Manager - Makes a final Approval/Denial decision based on the application factors. It also explains why a specific application is Approved/Denied.
#
# ### Pre-requisites
#
# 1. Signup on [FloTorch.ai](https://www.flotorch.ai/).
# 2. Follow the Getting Started guide.
# 3. Pre-configured agents on the FloTorch platform.
# 4. FloTorch AI gateway key.

# %%
import nest_asyncio
nest_asyncio.apply()
## This is needed only for google colab - run LangGraph async code in Colab cells without errors

# %%
# %pip install "flotorch[langgraph]" # production version
# Out:
# Requirement already satisfied: flotorch[langgraph] in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: httpx>=0.24 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.28.1)
# Requirement already satisfied: pydantic>=1.10 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (2.11.9)
# Requirement already satisfied: langgraph>=0.6.6 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.6.7)
# Requirement already satisfied: langgraph-checkpoint>=2.1.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt>=0.6.4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.6.4)
# Requirement already satisfied: langgraph-sdk>=0.2.3 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.2.9)
# Requirement already satisfied: langchain-core>=0.2.14 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.3.76)
# Requirement already satisfied: langchain-community>=0.3.27 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.3.29)
# Requirement already satisfied: langchain-openai>=0.3.30 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.3.33)
# Requirement already satisfied: langchain-mcp-adapters>=0.1.9 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.1.10)
# Requirement already satisfied: mcp>=1.13.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (1.14.1)
# Requirement already satisfied: anyio in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from httpx>=0.24->flotorch[langgraph]) (4.10.0)
# Requirement already satisfied: certifi in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from httpx>=0.24->flotorch[langgraph]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from httpx>=0.24->flotorch[langgraph]) (1.0.9)
# Requirement already satisfied: idna in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from httpx>=0.24->flotorch[langgraph]) (3.7)
# Requirement already satisfied: h11>=0.16 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24->flotorch[langgraph]) (0.16.0)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (2.0.43)
# Requirement already satisfied: requests<3,>=2.32.5 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (0.4.30)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-community>=0.3.27->flotorch[langgraph]) (2.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->flotorch[langgraph]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->flotorch[langgraph]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->flotorch[langgraph]) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->flotorch[langgraph]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->flotorch[langgraph]) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->flotorch[langgraph]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->flotorch[langgraph]) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community>=0.3.27->flotorch[langgraph]) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community>=0.3.27->flotorch[langgraph]) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community>=0.3.27->flotorch[langgraph]) (0.3.11)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-core>=0.2.14->flotorch[langgraph]) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-core>=0.2.14->flotorch[langgraph]) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-core>=0.2.14->flotorch[langgraph]) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.2.14->flotorch[langgraph]) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from pydantic>=1.10->flotorch[langgraph]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from pydantic>=1.10->flotorch[langgraph]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from pydantic>=1.10->flotorch[langgraph]) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community>=0.3.27->flotorch[langgraph]) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from requests<3,>=2.32.5->langchain-community>=0.3.27->flotorch[langgraph]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from requests<3,>=2.32.5->langchain-community>=0.3.27->flotorch[langgraph]) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community>=0.3.27->flotorch[langgraph]) (1.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-openai>=0.3.30->flotorch[langgraph]) (1.109.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-openai>=0.3.30->flotorch[langgraph]) (0.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai>=0.3.30->flotorch[langgraph]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai>=0.3.30->flotorch[langgraph]) (0.11.0)
# Requirement already satisfied: sniffio in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai>=0.3.30->flotorch[langgraph]) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai>=0.3.30->flotorch[langgraph]) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.3.30->flotorch[langgraph]) (2025.9.18)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langgraph>=0.6.6->flotorch[langgraph]) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langgraph-checkpoint>=2.1.1->flotorch[langgraph]) (1.10.0)
# Requirement already satisfied: orjson>=3.10.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langgraph-sdk>=0.2.3->flotorch[langgraph]) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community>=0.3.27->flotorch[langgraph]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community>=0.3.27->flotorch[langgraph]) (0.25.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (4.25.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.1->flotorch[langgraph]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.1->flotorch[langgraph]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.1->flotorch[langgraph]) (0.22.3)
# Requirement already satisfied: click>=7.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from uvicorn>=0.31.1->mcp>=1.13.1->flotorch[langgraph]) (8.3.0)
# Requirement already satisfied: langchain-experimental>=0.3.4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.3.4)
# Requirement already satisfied: sniffio in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai>=0.3.30->flotorch[langgraph]) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai>=0.3.30->flotorch[langgraph]) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.3.30->flotorch[langgraph]) (2025.9.18)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langgraph>=0.6.6->flotorch[langgraph]) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langgraph-checkpoint>=2.1.1->flotorch[langgraph]) (1.10.0)
# Requirement already satisfied: orjson>=3.10.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langgraph-sdk>=0.2.3->flotorch[langgraph]) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community>=0.3.27->flotorch[langgraph]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community>=0.3.27->flotorch[langgraph]) (0.25.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (4.25.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from mcp>=1.13.1->flotorch[langgraph]) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.1->flotorch[langgraph]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.1->flotorch[langgraph]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.1->flotorch[langgraph]) (0.22.3)
# Requirement already satisfied: click>=7.0 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from uvicorn>=0.31.1->mcp>=1.13.1->flotorch[langgraph]) (8.3.0)
# Requirement already satisfied: langchain-experimental>=0.3.4 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.3.4)
# Requirement already satisfied: langchain-mcp-tools>=0.2.13 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.2.13)
# Requirement already satisfied: langchain-mcp>=0.2.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.2.1)
# Requirement already satisfied: jsonschema-pydantic>=0.6 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-mcp-tools>=0.2.13->flotorch[langgraph]) (0.6)
# Requirement already satisfied: langchain-mcp-tools>=0.2.13 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.2.13)
# Requirement already satisfied: langchain-mcp>=0.2.1 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from flotorch[langgraph]) (0.2.1)
# Requirement already satisfied: jsonschema-pydantic>=0.6 in /Users/satyasrikantmantha/opt/anaconda3/envs/ft_notebooks/lib/python3.11/site-packages (from langchain-mcp-tools>=0.2.13->flotorch[langgraph]) (0.6)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from flotorch.langgraph.agent import FlotorchLangGraphAgent

# %%
# Configuration (set your API key)
# -----------------------------
FLOTORCH_GATEWAY_BASE_URL = "https://gateway.flotorch.cloud"
FLOTORCH_API_KEY = "<FLOTORCH_API_KEY>"
AGENTS = {
    "loan_parser": "loan-parser",
    "credit_analyzer": "credit-risk-analyzer",
    "risk_assessor": "risk-assessor"
}

# %% [markdown]
# When prompted for input, please enter the following:
#
# ```
# Name: Jane Doe
# Age: 35
# Income: 200000
# Loan Amount: 35000
# Credit Score: 720
# Existing Liabilities: 150000
# Purpose: Medical Emergency
# ```

# %%
# Name of the agent configured in Flotorch

# --- Build Agent from Flotorch Gateway config ---

flotorch_langgraph_client = FlotorchLangGraphAgent(
    agent_name=AGENTS['loan_parser'],
    api_key=FLOTORCH_API_KEY,
    base_url=FLOTORCH_GATEWAY_BASE_URL
)

# Get the LangGraph Agent from Flotorch Gateway
agent = flotorch_langgraph_client.get_agent()

# Get user input
query = input("You: ")

response = agent.invoke({"messages": query})

# 1. Direct content (string)
ai_content = response['messages'][-1].content

# 2.Credit Risk anlyser agent
flotorch_langgraph_client = FlotorchLangGraphAgent(
    agent_name=AGENTS['credit_analyzer'],
    api_key=FLOTORCH_API_KEY,
    base_url=FLOTORCH_GATEWAY_BASE_URL
)

agent = flotorch_langgraph_client.get_agent()
response = agent.invoke({"messages": ai_content})
ai_content2 = response['messages'][-1].content

#3rd agent - risk assessor
flotorch_langgraph_client = FlotorchLangGraphAgent(
    agent_name=AGENTS['risk_assessor'],
    api_key=FLOTORCH_API_KEY,
    base_url=FLOTORCH_GATEWAY_BASE_URL
)
agent = flotorch_langgraph_client.get_agent()

response = agent.invoke({"messages": ai_content2})
ai_content3 = response['messages'][-1].content
print(f"final agent response:::::::: :::::{ai_content3}")
# Out:
# 2025-09-23 16:40:14 - flotorch.sdk.llm - INFO - FlotorchLLM initialized (model_id=flotorch/insurance-llm:latest, base_url=https://gateway.flotorch.cloud)
# 2025-09-23 16:40:20 - flotorch.sdk.llm - INFO - LLM Request - model: flotorch/insurance-llm:latest, messages-length: 2
# 2025-09-23 16:40:20 - flotorch.sdk.llm - INFO - User Query: Name: Jane Doe Age: 35 Income: 200000 Loan Amount: 35000 Credit Score: 720 Existing Liabilities: 150000 Purpose: Medical Emergency
# 2025-09-23 16:40:20 - flotorch.sdk.llm - INFO - LLM Request - model: flotorch/insurance-llm:latest, messages-length: 2
# 2025-09-23 16:40:20 - flotorch.sdk.llm - INFO - User Query: Name: Jane Doe Age: 35 Income: 200000 Loan Amount: 35000 Credit Score: 720 Existing Liabilities: 150000 Purpose: Medical Emergency
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Response - model: flotorch/insurance-llm:latest, tokens: 695 (575+120)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - Final Response: {
#   "loan_summary": "Jane Doe (35) requests 35000 loan for Medical Emergency; income 200000; credit score 720.",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "income": 200000,
#     "loan_amount": 35000,
#     "credit_score": 720,
#     "existing_liabilities": 150000,
#     "purpose": "Medical Emergency"
#   }
# }
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Response - model: flotorch/insurance-llm:latest, tokens: 695 (575+120)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - Final Response: {
#   "loan_summary": "Jane Doe (35) requests 35000 loan for Medical Emergency; income 200000; credit score 720.",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "income": 200000,
#     "loan_amount": 35000,
#     "credit_score": 720,
#     "existing_liabilities": 150000,
#     "purpose": "Medical Emergency"
#   }
# }
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - FlotorchLLM initialized (model_id=flotorch/insurance-llm:latest, base_url=https://gateway.flotorch.cloud)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Request - model: flotorch/insurance-llm:latest, messages-length: 2
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - User Query: {
#   "loan_summary": "Jane Doe (35) requests 35000 loan for Medical Emergency; income 200000; credit score 720.",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "income": 200000,
#     "loan_amount": 35000,
#     "credit_score": 720,
#     "existing_liabilities": 150000,
#     "purpose": "Medica...
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - FlotorchLLM initialized (model_id=flotorch/insurance-llm:latest, base_url=https://gateway.flotorch.cloud)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Request - model: flotorch/insurance-llm:latest, messages-length: 2
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - User Query: {
#   "loan_summary": "Jane Doe (35) requests 35000 loan for Medical Emergency; income 200000; credit score 720.",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "income": 200000,
#     "loan_amount": 35000,
#     "credit_score": 720,
#     "existing_liabilities": 150000,
#     "purpose": "Medica...
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Response - model: flotorch/insurance-llm:latest, tokens: 909 (758+151)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - Final Response: {
#   "credit_assessment": "Credit score 720 is excellent, but DTI of 92.5% (existing liabilities $150k + requested $35k vs $200k income) presents significant repayment risk despite emergency nature of loan.",
#   "credit_rating": "Medium",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "income": 200000,
#     "loan_amount": 35000,
#     "credit_score": 720,
#     "existing_liabilities": 150000,
#     "purpose": "Medical Emergency"
#   }
# }
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Response - model: flotorch/insurance-llm:latest, tokens: 909 (758+151)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - Final Response: {
#   "credit_assessment": "Credit score 720 is excellent, but DTI of 92.5% (existing liabilities $150k + requested $35k vs $200k income) presents significant repayment risk despite emergency nature of loan.",
#   "credit_rating": "Medium",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "income": 200000,
#     "loan_amount": 35000,
#     "credit_score": 720,
#     "existing_liabilities": 150000,
#     "purpose": "Medical Emergency"
#   }
# }
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - FlotorchLLM initialized (model_id=flotorch/insurance-llm:latest, base_url=https://gateway.flotorch.cloud)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Request - model: flotorch/insurance-llm:latest, messages-length: 2
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - User Query: {
#   "credit_assessment": "Credit score 720 is excellent, but DTI of 92.5% (existing liabilities $150k + requested $35k vs $200k income) presents significant repayment risk despite emergency nature of loan.",
#   "credit_rating": "Medium",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "in...
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - FlotorchLLM initialized (model_id=flotorch/insurance-llm:latest, base_url=https://gateway.flotorch.cloud)
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - LLM Request - model: flotorch/insurance-llm:latest, messages-length: 2
# 2025-09-23 16:40:23 - flotorch.sdk.llm - INFO - User Query: {
#   "credit_assessment": "Credit score 720 is excellent, but DTI of 92.5% (existing liabilities $150k + requested $35k vs $200k income) presents significant repayment risk despite emergency nature of loan.",
#   "credit_rating": "Medium",
#   "loan_data": {
#     "name": "Jane Doe",
#     "age": 35,
#     "in...
# 2025-09-23 16:40:24 - flotorch.sdk.llm - INFO - LLM Response - model: flotorch/insurance-llm:latest, tokens: 810 (713+97)
# 2025-09-23 16:40:24 - flotorch.sdk.llm - INFO - Final Response: {
#   "loan_decision": "Denied",
#   "risk_assessment": "Despite excellent credit score of 720 and emergency medical purpose, the DTI ratio of 92.5% significantly exceeds acceptable lending standards and poses substantial repayment risk. The borrower's existing liabilities of $150k combined with the requested $35k loan would create unsustainable debt burden relative to $200k annual income."
# }
# final agent response:::::::: :::::{
#   "loan_decision": "Denied",
#   "risk_assessment": "Despite excellent credit score of 720 and emergency medical purpose, the DTI ratio of 92.5% significantly exceeds acceptable lending standards and poses substantial repayment risk. The borrower's existing liabilities of $150k combined with the requested $35k loan would create unsustainable debt burden relative to $200k annual income."
# }
# 2025-09-23 16:40:24 - flotorch.sdk.llm - INFO - LLM Response - model: flotorch/insurance-llm:latest, tokens: 810 (713+97)
# 2025-09-23 16:40:24 - flotorch.sdk.llm - INFO - Final Response: {
#   "loan_decision": "Denied",
#   "risk_assessment": "Despite excellent credit score of 720 and emergency medical purpose, the DTI ratio of 92.5% significantly exceeds acceptable lending standards and poses substantial repayment risk. The borrower's existing liabilities of $150k combined with the requested $35k loan would create unsustainable debt burden relative to $200k annual income."
# }
# final agent response:::::::: :::::{
#   "loan_decision": "Denied",
#   "risk_assessment": "Despite excellent credit score of 720 and emergency medical purpose, the DTI ratio of 92.5% significantly exceeds acceptable lending standards and poses substantial repayment risk. The borrower's existing liabilities of $150k combined with the requested $35k loan would create unsustainable debt burden relative to $200k annual income."
# }
